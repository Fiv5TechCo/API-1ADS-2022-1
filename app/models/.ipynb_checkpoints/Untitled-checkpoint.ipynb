# %%
import pandas as pd

metricas_df = pd.read_csv('for_Metricas.csv', encoding = 'UTF-8')
display(metricas_df)
# Out:
#     Unnamed: 0                                            subject  \
# 0            0             Vaga de Analista de DP em São Paulo/SP
# 1            1            Vaga de Adesivador em Rio de Janeiro/RJ
# 2            2           Vaga de Operador de Caixa em Curitiba/PR
# 3            3               Vaga de Técnico de Ti em Tomé-Açú/PA
# 4            4    Vaga de Assistente Administrativo em Tijucas/SC
# 5            5                   Vaga de Garçonete em Brasília/DF
# 6            6            Vaga de Assistente Fiscal em Goiânia/GO
# 7            7                   Vaga de Fotógrafo em Curitiba/PR
# 8            8            Vaga de Leiturista em Rio de Janeiro/RJ
# 9            9    Vaga de Motorista em Cachoeiro de Itapemirim/ES
# 10          10  Vaga de Técnico de Informática em Duque de Cax...
# 11          11    Vaga de Panfleteiro em São José do Rio Pardo/SP
# 12          12         Vaga de Servente de Limpeza em Curitiba/PR
# 13          13             Vaga de Panfleteiro em Pirassununga/SP
# 14          14  Vaga de Representante Comercial em Caldas Nova...
# 15          15        Vaga de Vendedor Interno em Pirassununga/SP
# 16          16                     Vaga de Garçom em São Paulo/SP
# 17          17                  Vaga de Eletricista em Vitória/ES
# 18          18  Vaga de Vendedor Interno em São José do Rio Pa...
# 19          19  Vaga de Médico Veterinário em São José do Rio ...
# 20          20         Vaga de Vendedor Externo em Brejo Santo/CE
# 21          21               Vaga de Recepcionista em Curitiba/PR
# 22          22      Vaga de Médico Veterinário em Pirassununga/SP
# 23          23                     Vaga de Doméstica em Cuiabá/MT
# 24          24          Vaga de Promotor de Vendas em São Luís/MA
# 25          25             Vaga de Vendedor Externo em Itapajé/CE
# 26          26                 Vaga de Vendedor em Barra Velha/SC
# 27          27             Vaga de Estagiário em Florianópolis/SC
# 28          28            Vaga de Vendedor Externo em Beberibe/CE
# 29          29   Vaga de Representante Comercial em Boa Viagem/CE
#
#                          task                                 place  \
# 0              Analista de DP            Zona Sul ,  São Paulo / SP
# 1                  Adesivador                   Rio de Janeiro / RJ
# 2           Operador de Caixa                         Curitiba / PR
# 3               Técnico de Ti                         Tomé-Açú / PA
# 4   Assistente Administrativo                          Tijucas / SC
# 5                   Garçonete                         Brasília / DF
# 6           Assistente Fiscal                          Goiânia / GO
# 7                   Fotógrafo  Campina Do Siqueira ,  Curitiba / PR
# 8                  Leiturista                   Rio de Janeiro / RJ
# 9                   Motorista          Cachoeiro de Itapemirim / ES
# 10     Técnico de Informática                  Duque de Caxias / RJ
# 11                Panfleteiro            São José do Rio Pardo / SP
# 12        Servente de Limpeza                         Curitiba / PR
# 13                Panfleteiro                     Pirassununga / SP
# 14    Representante Comercial                     Caldas Novas / GO
# 15           Vendedor Interno                     Pirassununga / SP
# 16                     Garçom                        São Paulo / SP
# 17                Eletricista                          Vitória / ES
# 18           Vendedor Interno            São José do Rio Pardo / SP
# 19         Médico Veterinário            São José do Rio Pardo / SP
# 20           Vendedor Externo                      Brejo Santo / CE
# 21              Recepcionista                CENTRO,  Curitiba / PR
# 22         Médico Veterinário                     Pirassununga / SP
# 23                  Doméstica                           Cuiabá / MT
# 24         Promotor de Vendas                         São Luís / MA
# 25           Vendedor Externo                          Itapajé / CE
# 26                   Vendedor                      Barra Velha / SC
# 27                 Estagiário                    Florianópolis / SC
# 28           Vendedor Externo                         Beberibe / CE
# 29    Representante Comercial                       Boa Viagem / CE
#
#                                city state                       wage  \
# 0             Zona Sul ,  São Paulo    SP  R$ 3.000,00 a R$ 3.500,00
# 1                    Rio de Janeiro    RJ                 a combinar
# 2                          Curitiba    PR                R$ 1.553,20
# 3                          Tomé-Açú    PA                 a combinar
# 4                           Tijucas    SC                 a combinar
# 5                          Brasília    DF                 a combinar
# 6                           Goiânia    GO                 a combinar
# 7   Campina Do Siqueira ,  Curitiba    PR                R$ 1.400,00
# 8                    Rio de Janeiro    RJ                 a combinar
# 9           Cachoeiro de Itapemirim    ES                 a combinar
# 10                  Duque de Caxias    RJ                 a combinar
# 11            São José do Rio Pardo    SP                 a combinar
# 12                         Curitiba    PR  R$ 1.045,00 a R$ 1.500,00
# 13                     Pirassununga    SP                 a combinar
# 14                     Caldas Novas    GO                 a combinar
# 15                     Pirassununga    SP                 a combinar
# 16                        São Paulo    SP                 a combinar
# 17                          Vitória    ES                 a combinar
# 18            São José do Rio Pardo    SP                 a combinar
# 19            São José do Rio Pardo    SP                 a combinar
# 20                      Brejo Santo    CE                 a combinar
# 21                CENTRO,  Curitiba    PR                R$ 1.522,00
# 22                     Pirassununga    SP                 a combinar
# 23                           Cuiabá    MT                 a combinar
# 24                         São Luís    MA                 a combinar
# 25                          Itapajé    CE                 a combinar
# 26                      Barra Velha    SC  R$ 1.200,00 a R$ 2.500,00
# 27                    Florianópolis    SC                R$ 1.045,00
# 28                         Beberibe    CE                 a combinar
# 29                       Boa Viagem    CE                 a combinar
#
#                                               company
# 0   Agilidade Gestão de Pessoas e Soluções em RH -...
# 1                                              Master
# 2         Mixtel Distribuidora - Ver dados da empresa
# 3                        Centro Oeste Teleinformática
# 4                                     Pestana Leilões
# 5        Restaurante Saudável - Localizado Na Asa Sul
# 6                                  Leal Contabilidade
# 7                  ZAFT MODELS - Ver dados da empresa
# 8       Hidrolight Equipamentos e Serviços Eireli Epp
# 9                                       Parceiro Spot
# 10                                     Sd Informatica
# 11                        Paixão e Massa Treinamentos
# 12                         Confidencial O que é isso?
# 13                        Paixão e Massa Treinamentos
# 14                       Solaris Pharma Brazil Eireli
# 15                        Paixão e Massa Treinamentos
# 16                         Mirante do Carmo Gastrobar
# 17                             Mge Medições Elétricas
# 18                        Paixão e Massa Treinamentos
# 19                        Paixão e Massa Treinamentos
# 20                     Ecopower Eficiência Energética
# 21  CEMITERIO PARQUE DAS ARAUCARIAS - Ver dados da...
# 22                        Paixão e Massa Treinamentos
# 23                                    Casa de Familia
# 24                                        Gav Resorts
# 25                     Ecopower Eficiência Energética
# 26                         Confidencial O que é isso?
# 27                Smartlipo Serviços de Estetica Ltda
# 28                     Ecopower Eficiência Energética
# 29                     Ecopower Eficiência Energética

# %%
metricas_df1 = metricas_df[['task', 'state']]
display(metricas_df1)
# Out:
#                          task state
# 0              Analista de DP    SP
# 1                  Adesivador    RJ
# 2           Operador de Caixa    PR
# 3               Técnico de Ti    PA
# 4   Assistente Administrativo    SC
# 5                   Garçonete    DF
# 6           Assistente Fiscal    GO
# 7                   Fotógrafo    PR
# 8                  Leiturista    RJ
# 9                   Motorista    ES
# 10     Técnico de Informática    RJ
# 11                Panfleteiro    SP
# 12        Servente de Limpeza    PR
# 13                Panfleteiro    SP
# 14    Representante Comercial    GO
# 15           Vendedor Interno    SP
# 16                     Garçom    SP
# 17                Eletricista    ES
# 18           Vendedor Interno    SP
# 19         Médico Veterinário    SP
# 20           Vendedor Externo    CE
# 21              Recepcionista    PR
# 22         Médico Veterinário    SP
# 23                  Doméstica    MT
# 24         Promotor de Vendas    MA
# 25           Vendedor Externo    CE
# 26                   Vendedor    SC
# 27                 Estagiário    SC
# 28           Vendedor Externo    CE
# 29    Representante Comercial    CE

# %%
dfremove = metricas_df1.loc[(metricas_df1['state']!='SP')]
metricas_final = metricas_df1.drop(dfremove.index)
metricasfinal_2 = metricas_final.groupby(metricas_final['task']).count().reset_index()
display(metricasfinal_2)
# Out:
#                  task  state
# 0      Analista de DP      1
# 1              Garçom      1
# 2  Médico Veterinário      2
# 3         Panfleteiro      2
# 4    Vendedor Interno      2

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (25, 8))
plt.bar(metricasfinal_2['task'], metricasfinal_2['state'])
plt.yticks([0, 1, 2])
plt.axis('auto')
plt.ylabel('Número de Vagas')
plt.xlabel('Cargos')
plt.title('São Paulo')
plt.savefig('grafico.png', format='png', dpi=300, bbox_inches='tight')
plt.show()
